# %%
import matplotlib.pyplot as plt
import numpy as np
import galsim
from astropy.io import fits
from diverse_utils import create_and_save_gal
import sys
sys.path.append('../')
from telescopes.main_info import info

# %%
for i in range(4, 5):
    create_and_save_gal(info, 'Chandra', 'HRC', i, True)

# %%
create_and_save_gal(info, 'SDSS', 'Imaging_camera', 3, True)

# %%
create_and_save_gal(info, 'Rubin', 'Wide-field-imager', 3, True)

# %%
create_and_save_gal(info, 'HST', 'ACS', 3, True)

# %%
create_and_save_gal(info, 'JWST', 'NIRCAM', 3, True)

# %%
create_and_save_gal(info, 'Euclid', 'VIS', 3, True)

# %%
create_and_save_gal(info, 'Euclid', 'NIR', 3, True)
